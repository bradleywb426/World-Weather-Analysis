# %%
import numpy as np
import random
from citipy import citipy
import requests
from config import weather_api_key
import pandas as pd
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("-----------------------------")
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | santarem
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | ingham
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | alekseyevsk
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | bilibino
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | mount isa
# Processing Record 17 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | bambous virieux
# Processing Record 20 of Set 1 | metro
# Processing Record 21 of Set 1 | deer lake
# Processing Record 22 of Set 1 | kluang
# Processing Record 23 of Set 1 | beidao
# Processing Record 24 of Set 1 | bengkulu
# Processing Record 25 of Set 1 | tambacounda
# Processing Record 26 of Set 1 | yaan
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | lagoa
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | bhind
# Processing Record 33 of Set 1 | pastavy
# Processing Record 34 of Set 1 | mount gambier
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | guarapari
# Processing Record 37 of Set 1 | solana beach
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | liwale
# Processing Record 40 of Set 1 | beloha
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | nanortalik
# Processing Record 44 of Set 1 | athabasca
# Processing Record 45 of Set 1 | constitucion
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | arnedo
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | bodden town
# Processing Record 2 of Set 2 | upernavik
# Processing Record 3 of Set 2 | alice springs
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | vestmannaeyjar
# Processing Record 6 of Set 2 | iqaluit
# Processing Record 7 of Set 2 | broome
# Processing Record 8 of Set 2 | kampene
# Processing Record 9 of Set 2 | yellowknife
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | broken hill
# Processing Record 12 of Set 2 | vanimo
# Processing Record 13 of Set 2 | bethel
# Processing Record 14 of Set 2 | vila velha
# Processing Record 15 of Set 2 | ponta delgada
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | ushuaia
# Processing Record 18 of Set 2 | marovoay
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | saint-philippe
# Processing Record 21 of Set 2 | srednekolymsk
# Processing Record 22 of Set 2 | kochevo
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 2 | souillac
# Processing Record 26 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 2 | jacareacanga
# Processing Record 29 of Set 2 | new norfolk
# Processing Record 30 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 2 | namibe
# Processing Record 32 of Set 2 | chapleau
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | richards bay
# Processing Record 35 of Set 2 | kaeo
# Processing Record 36 of Set 2 | port elizabeth
# Processing Record 37 of Set 2 | umea
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | san ramon de la nueva oran
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | tocopilla
# Processing Record 42 of Set 2 | cherskiy
# Processing Record 43 of Set 2 | mahebourg
# Processing Record 44 of Set 2 | gboko
# Processing Record 45 of Set 2 | port augusta
# Processing Record 46 of Set 2 | kavieng
# Processing Record 47 of Set 2 | tazovskiy
# Processing Record 48 of Set 2 | olinda
# Processing Record 49 of Set 2 | bowmore
# Processing Record 50 of Set 2 | sambava
# Processing Record 1 of Set 3 | mayo
# Processing Record 2 of Set 3 | olafsvik
# Processing Record 3 of Set 3 | kaitangata
# Processing Record 4 of Set 3 | pithoragarh
# Processing Record 5 of Set 3 | tiruchchendur
# Processing Record 6 of Set 3 | bondoukou
# Processing Record 7 of Set 3 | coihaique
# Processing Record 8 of Set 3 | longyearbyen
# Processing Record 9 of Set 3 | erbaa
# Processing Record 10 of Set 3 | tessalit
# Processing Record 11 of Set 3 | sarkand
# Processing Record 12 of Set 3 | kedougou
# Processing Record 13 of Set 3 | fortuna
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | perth
# Processing Record 16 of Set 3 | chuy
# Processing Record 17 of Set 3 | hobart
# Processing Record 18 of Set 3 | bogorodsk
# Processing Record 19 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 20 of Set 3 | banda aceh
# Processing Record 21 of Set 3 | seoul
# Processing Record 22 of Set 3 | harper
# Processing Record 23 of Set 3 | shelburne
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | kuminskiy
# Processing Record 26 of Set 3 | santa isabel do rio negro
# Processing Record 27 of Set 3 | port-gentil
# Processing Record 28 of Set 3 | berlevag
# Processing Record 29 of Set 3 | aripuana
# Processing Record 30 of Set 3 | kapaa
# Processing Record 31 of Set 3 | yumen
# Processing Record 32 of Set 3 | minna
# Processing Record 33 of Set 3 | cape town
# Processing Record 34 of Set 3 | agadez
# Processing Record 35 of Set 3 | iberia
# Processing Record 36 of Set 3 | guerrero negro
# Processing Record 37 of Set 3 | wilkie
# Processing Record 38 of Set 3 | neuquen
# Processing Record 39 of Set 3 | pacific grove
# Processing Record 40 of Set 3 | tiksi
# Processing Record 41 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 3 | marsh harbour
# Processing Record 44 of Set 3 | kieta
# Processing Record 45 of Set 3 | la ronge
# Processing Record 46 of Set 3 | hofn
# Processing Record 47 of Set 3 | najran
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | ponta do sol
# Processing Record 50 of Set 3 | westport
# Processing Record 1 of Set 4 | katghora
# Processing Record 2 of Set 4 | tenenkou
# Processing Record 3 of Set 4 | hualmay
# Processing Record 4 of Set 4 | nikolskoye
# Processing Record 5 of Set 4 | lebu
# Processing Record 6 of Set 4 | magadan
# Processing Record 7 of Set 4 | pevek
# Processing Record 8 of Set 4 | viedma
# Processing Record 9 of Set 4 | camacha
# Processing Record 10 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 11 of Set 4 | vila franca do campo
# Processing Record 12 of Set 4 | sur
# Processing Record 13 of Set 4 | eidsvoll
# Processing Record 14 of Set 4 | pouebo
# Processing Record 15 of Set 4 | dingli
# Processing Record 16 of Set 4 | sao gabriel da cachoeira
# Processing Record 17 of Set 4 | belyy yar
# Processing Record 18 of Set 4 | buala
# Processing Record 19 of Set 4 | aksu
# Processing Record 20 of Set 4 | salalah
# Processing Record 21 of Set 4 | rantauprapat
# Processing Record 22 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 4 | mabaruma
# Processing Record 24 of Set 4 | tahoua
# Processing Record 25 of Set 4 | caraballeda
# Processing Record 26 of Set 4 | faanui
# Processing Record 27 of Set 4 | phillipsburg
# Processing Record 28 of Set 4 | fairbanks
# Processing Record 29 of Set 4 | sungaipenuh
# Processing Record 30 of Set 4 | ribeira grande
# Processing Record 31 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 4 | solnechnyy
# Processing Record 33 of Set 4 | saint-georges
# Processing Record 34 of Set 4 | werda
# Processing Record 35 of Set 4 | guelengdeng
# City not found. Skipping...
# Processing Record 36 of Set 4 | alyangula
# Processing Record 37 of Set 4 | tuatapere
# Processing Record 38 of Set 4 | fez
# Processing Record 39 of Set 4 | sao joao da barra
# Processing Record 40 of Set 4 | rigaud
# Processing Record 41 of Set 4 | batticaloa
# Processing Record 42 of Set 4 | kropotkin
# Processing Record 43 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 44 of Set 4 | feijo
# Processing Record 45 of Set 4 | abancay
# Processing Record 46 of Set 4 | pochutla
# Processing Record 47 of Set 4 | dispur
# Processing Record 48 of Set 4 | kysyl-syr
# Processing Record 49 of Set 4 | aklavik
# Processing Record 50 of Set 4 | saldanha
# Processing Record 1 of Set 5 | rodrigues alves
# Processing Record 2 of Set 5 | portland
# Processing Record 3 of Set 5 | xingyi
# Processing Record 4 of Set 5 | lagos
# Processing Record 5 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 5 | egvekinot
# Processing Record 7 of Set 5 | plouzane
# Processing Record 8 of Set 5 | togur
# Processing Record 9 of Set 5 | tostamaa
# City not found. Skipping...
# Processing Record 10 of Set 5 | saint-pierre
# Processing Record 11 of Set 5 | shieli
# Processing Record 12 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 5 | bambanglipuro
# Processing Record 14 of Set 5 | ahipara
# Processing Record 15 of Set 5 | ulladulla
# Processing Record 16 of Set 5 | neyshabur
# Processing Record 17 of Set 5 | baherden
# Processing Record 18 of Set 5 | robinson
# Processing Record 19 of Set 5 | sorland
# Processing Record 20 of Set 5 | dabat
# Processing Record 21 of Set 5 | morondava
# Processing Record 22 of Set 5 | provideniya
# Processing Record 23 of Set 5 | porto novo
# Processing Record 24 of Set 5 | chaihe
# Processing Record 25 of Set 5 | batemans bay
# Processing Record 26 of Set 5 | grand gaube
# Processing Record 27 of Set 5 | zanzibar
# Processing Record 28 of Set 5 | college
# Processing Record 29 of Set 5 | thompson
# Processing Record 30 of Set 5 | jiangkou
# Processing Record 31 of Set 5 | maniitsoq
# Processing Record 32 of Set 5 | esperance
# Processing Record 33 of Set 5 | sinnar
# Processing Record 34 of Set 5 | vila do maio
# Processing Record 35 of Set 5 | morant bay
# Processing Record 36 of Set 5 | sanchazi
# Processing Record 37 of Set 5 | nantucket
# Processing Record 38 of Set 5 | klaksvik
# Processing Record 39 of Set 5 | antsohihy
# Processing Record 40 of Set 5 | clyde river
# Processing Record 41 of Set 5 | manoel urbano
# Processing Record 42 of Set 5 | uberlandia
# Processing Record 43 of Set 5 | paamiut
# Processing Record 44 of Set 5 | stornoway
# Processing Record 45 of Set 5 | black forest
# Processing Record 46 of Set 5 | san ramon
# Processing Record 47 of Set 5 | te anau
# Processing Record 48 of Set 5 | doba
# Processing Record 49 of Set 5 | darhan
# Processing Record 50 of Set 5 | abalak
# Processing Record 1 of Set 6 | cayenne
# Processing Record 2 of Set 6 | birchis
# Processing Record 3 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 6 | hasaki
# Processing Record 5 of Set 6 | wakkanai
# Processing Record 6 of Set 6 | sitka
# Processing Record 7 of Set 6 | grindavik
# Processing Record 8 of Set 6 | luyang
# Processing Record 9 of Set 6 | san cristobal
# Processing Record 10 of Set 6 | bakurianis andeziti
# Processing Record 11 of Set 6 | rogun
# City not found. Skipping...
# Processing Record 12 of Set 6 | besancon
# Processing Record 13 of Set 6 | qaanaaq
# Processing Record 14 of Set 6 | suao
# City not found. Skipping...
# Processing Record 15 of Set 6 | knysna
# Processing Record 16 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 6 | carutapera
# Processing Record 18 of Set 6 | san patricio
# Processing Record 19 of Set 6 | zambezi
# Processing Record 20 of Set 6 | iracoubo
# Processing Record 21 of Set 6 | lima
# Processing Record 22 of Set 6 | eyl
# Processing Record 23 of Set 6 | kaseda
# Processing Record 24 of Set 6 | port blair
# Processing Record 25 of Set 6 | isangel
# Processing Record 26 of Set 6 | hajnowka
# Processing Record 27 of Set 6 | tomatlan
# Processing Record 28 of Set 6 | popondetta
# Processing Record 29 of Set 6 | castro
# Processing Record 30 of Set 6 | kavaratti
# Processing Record 31 of Set 6 | mastic beach
# Processing Record 32 of Set 6 | codrington
# Processing Record 33 of Set 6 | boa vista
# Processing Record 34 of Set 6 | airai
# Processing Record 35 of Set 6 | pasighat
# Processing Record 36 of Set 6 | chiang rai
# Processing Record 37 of Set 6 | mahon
# Processing Record 38 of Set 6 | necochea
# Processing Record 39 of Set 6 | pattani
# Processing Record 40 of Set 6 | yarada
# Processing Record 41 of Set 6 | vladicin han
# Processing Record 42 of Set 6 | kahului
# Processing Record 43 of Set 6 | gimli
# Processing Record 44 of Set 6 | faya
# Processing Record 45 of Set 6 | general roca
# Processing Record 46 of Set 6 | harwich
# Processing Record 47 of Set 6 | adet
# Processing Record 48 of Set 6 | tezu
# Processing Record 49 of Set 6 | nicolas bravo
# Processing Record 50 of Set 6 | atar
# Processing Record 1 of Set 7 | tarancon
# Processing Record 2 of Set 7 | les cayes
# Processing Record 3 of Set 7 | jiangyou
# Processing Record 4 of Set 7 | srandakan
# Processing Record 5 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 7 | port lincoln
# Processing Record 7 of Set 7 | shenjiamen
# Processing Record 8 of Set 7 | taoudenni
# Processing Record 9 of Set 7 | tucupita
# Processing Record 10 of Set 7 | kem
# Processing Record 11 of Set 7 | cidreira
# Processing Record 12 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 7 | volginskiy
# City not found. Skipping...
# Processing Record 14 of Set 7 | grafton
# Processing Record 15 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 16 of Set 7 | krasnogvardeyskiy
# Processing Record 17 of Set 7 | barcelona
# Processing Record 18 of Set 7 | touros
# Processing Record 19 of Set 7 | axim
# Processing Record 20 of Set 7 | kikwit
# Processing Record 21 of Set 7 | makakilo city
# Processing Record 22 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 7 | kohtla-jarve
# Processing Record 24 of Set 7 | ilulissat
# Processing Record 25 of Set 7 | tilichiki
# Processing Record 26 of Set 7 | manzhouli
# Processing Record 27 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 28 of Set 7 | afonso bezerra
# Processing Record 29 of Set 7 | narsaq
# Processing Record 30 of Set 7 | shibetsu
# Processing Record 31 of Set 7 | nome
# Processing Record 32 of Set 7 | san quintin
# Processing Record 33 of Set 7 | kingston
# Processing Record 34 of Set 7 | bathsheba
# Processing Record 35 of Set 7 | matara
# Processing Record 36 of Set 7 | penon blanco
# Processing Record 37 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 7 | port hardy
# Processing Record 39 of Set 7 | maldonado
# Processing Record 40 of Set 7 | pundaguitan
# Processing Record 41 of Set 7 | naze
# Processing Record 42 of Set 7 | ust-ilimsk
# Processing Record 43 of Set 7 | pangnirtung
# Processing Record 44 of Set 7 | hobyo
# Processing Record 45 of Set 7 | lafiagi
# Processing Record 46 of Set 7 | rio grande
# Processing Record 47 of Set 7 | itarema
# Processing Record 48 of Set 7 | tongren
# Processing Record 49 of Set 7 | camara de lobos
# Processing Record 50 of Set 7 | pudozh
# Processing Record 1 of Set 8 | ossora
# Processing Record 2 of Set 8 | zhanaozen
# Processing Record 3 of Set 8 | qaqortoq
# Processing Record 4 of Set 8 | manggar
# Processing Record 5 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 8 | nuuk
# Processing Record 7 of Set 8 | tymovskoye
# Processing Record 8 of Set 8 | kruisfontein
# Processing Record 9 of Set 8 | molochnoye
# Processing Record 10 of Set 8 | la rochelle
# Processing Record 11 of Set 8 | sao filipe
# Processing Record 12 of Set 8 | lazdijai
# Processing Record 13 of Set 8 | dukat
# Processing Record 14 of Set 8 | bako
# Processing Record 15 of Set 8 | caceres
# Processing Record 16 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 17 of Set 8 | kristiinankaupunki
# Processing Record 18 of Set 8 | waingapu
# Processing Record 19 of Set 8 | bubaque
# Processing Record 20 of Set 8 | yangliuqing
# Processing Record 21 of Set 8 | baoning
# Processing Record 22 of Set 8 | nizwa
# Processing Record 23 of Set 8 | san miguel
# Processing Record 24 of Set 8 | margate
# Processing Record 25 of Set 8 | ballina
# Processing Record 26 of Set 8 | labuhan
# Processing Record 27 of Set 8 | bilma
# Processing Record 28 of Set 8 | clarksdale
# Processing Record 29 of Set 8 | meilu
# City not found. Skipping...
# Processing Record 30 of Set 8 | inta
# Processing Record 31 of Set 8 | okato
# Processing Record 32 of Set 8 | yongan
# Processing Record 33 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 8 | pisco
# Processing Record 35 of Set 8 | lashio
# Processing Record 36 of Set 8 | fallon
# Processing Record 37 of Set 8 | burnie
# Processing Record 38 of Set 8 | coquimbo
# Processing Record 39 of Set 8 | moville
# Processing Record 40 of Set 8 | vidim
# Processing Record 41 of Set 8 | assiniboia
# Processing Record 42 of Set 8 | villefontaine
# Processing Record 43 of Set 8 | tabuk
# Processing Record 44 of Set 8 | synya
# Processing Record 45 of Set 8 | geraldton
# Processing Record 46 of Set 8 | yanam
# Processing Record 47 of Set 8 | luderitz
# Processing Record 48 of Set 8 | leningradskiy
# Processing Record 49 of Set 8 | lodja
# Processing Record 50 of Set 8 | mata
# Processing Record 1 of Set 9 | palu
# Processing Record 2 of Set 9 | karratha
# Processing Record 3 of Set 9 | phalaborwa
# Processing Record 4 of Set 9 | tecolutla
# Processing Record 5 of Set 9 | pavino
# Processing Record 6 of Set 9 | shimoda
# Processing Record 7 of Set 9 | itoman
# Processing Record 8 of Set 9 | padang
# Processing Record 9 of Set 9 | severo-kurilsk
# Processing Record 10 of Set 9 | morgan city
# Processing Record 11 of Set 9 | hambantota
# Processing Record 12 of Set 9 | kodinsk
# Processing Record 13 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 14 of Set 9 | ubinskoye
# Processing Record 15 of Set 9 | nishihara
# Processing Record 16 of Set 9 | jumla
# Processing Record 17 of Set 9 | byron bay
# Processing Record 18 of Set 9 | bardsir
# Processing Record 19 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 9 | jacksonville
# Processing Record 22 of Set 9 | mitsamiouli
# Processing Record 23 of Set 9 | lengshuijiang
# Processing Record 24 of Set 9 | anajatuba
# Processing Record 25 of Set 9 | kautokeino
# Processing Record 26 of Set 9 | vangaindrano
# Processing Record 27 of Set 9 | gaffney
# Processing Record 28 of Set 9 | komsomolskiy
# Processing Record 29 of Set 9 | sept-iles
# Processing Record 30 of Set 9 | mackay
# Processing Record 31 of Set 9 | caravelas
# Processing Record 32 of Set 9 | ambatolampy
# Processing Record 33 of Set 9 | murgab
# Processing Record 34 of Set 9 | taunggyi
# Processing Record 35 of Set 9 | mirnyy
# Processing Record 36 of Set 9 | haines junction
# Processing Record 37 of Set 9 | celestun
# Processing Record 38 of Set 9 | yinchuan
# Processing Record 39 of Set 9 | thinadhoo
# Processing Record 40 of Set 9 | ukiah
# Processing Record 41 of Set 9 | la moncada
# Processing Record 42 of Set 9 | uglovskoye
# Processing Record 43 of Set 9 | rafaela
# Processing Record 44 of Set 9 | banjar
# Processing Record 45 of Set 9 | skibbereen
# Processing Record 46 of Set 9 | glendive
# Processing Record 47 of Set 9 | lorengau
# Processing Record 48 of Set 9 | meulaboh
# Processing Record 49 of Set 9 | abashiri
# Processing Record 50 of Set 9 | kudahuvadhoo
# Processing Record 1 of Set 10 | conceicao do mato dentro
# Processing Record 2 of Set 10 | coahuayana
# Processing Record 3 of Set 10 | camana
# Processing Record 4 of Set 10 | borba
# Processing Record 5 of Set 10 | corrales
# Processing Record 6 of Set 10 | laurel
# Processing Record 7 of Set 10 | nouadhibou
# Processing Record 8 of Set 10 | yorkton
# Processing Record 9 of Set 10 | achisay
# City not found. Skipping...
# Processing Record 10 of Set 10 | anchorage
# Processing Record 11 of Set 10 | pilar
# Processing Record 12 of Set 10 | arvika
# Processing Record 13 of Set 10 | methven
# Processing Record 14 of Set 10 | plettenberg bay
# Processing Record 15 of Set 10 | isla vista
# Processing Record 16 of Set 10 | mackenzie
# Processing Record 17 of Set 10 | beisfjord
# Processing Record 18 of Set 10 | uvinza
# Processing Record 19 of Set 10 | huazolotitlan
# City not found. Skipping...
# Processing Record 20 of Set 10 | troitsko-pechorsk
# Processing Record 21 of Set 10 | choix
# Processing Record 22 of Set 10 | garoua
# Processing Record 23 of Set 10 | buritizeiro
# Processing Record 24 of Set 10 | santa fe
# Processing Record 25 of Set 10 | sabanalarga
# Processing Record 26 of Set 10 | micheweni
# Processing Record 27 of Set 10 | kenora
# Processing Record 28 of Set 10 | charagua
# Processing Record 29 of Set 10 | muroto
# Processing Record 30 of Set 10 | del rio
# Processing Record 31 of Set 10 | kuruman
# Processing Record 32 of Set 10 | talnakh
# Processing Record 33 of Set 10 | prince rupert
# Processing Record 34 of Set 10 | lasa
# Processing Record 35 of Set 10 | san jeronimo
# Processing Record 36 of Set 10 | poum
# Processing Record 37 of Set 10 | saint-paul
# Processing Record 38 of Set 10 | tirunelveli
# Processing Record 39 of Set 10 | nalut
# Processing Record 40 of Set 10 | norman wells
# Processing Record 41 of Set 10 | vagur
# Processing Record 42 of Set 10 | ratnagiri
# Processing Record 43 of Set 10 | bressanone
# Processing Record 44 of Set 10 | mitu
# Processing Record 45 of Set 10 | secunda
# Processing Record 46 of Set 10 | raudeberg
# Processing Record 47 of Set 10 | trairi
# Processing Record 48 of Set 10 | lata
# Processing Record 49 of Set 10 | tara
# Processing Record 50 of Set 10 | marquette
# Processing Record 1 of Set 11 | quelimane
# Processing Record 2 of Set 11 | shabqadar
# Processing Record 3 of Set 11 | sharjah
# Processing Record 4 of Set 11 | jacqueville
# Processing Record 5 of Set 11 | pandamatenga
# Processing Record 6 of Set 11 | stokmarknes
# Processing Record 7 of Set 11 | buraydah
# Processing Record 8 of Set 11 | fasa
# Processing Record 9 of Set 11 | aranda de duero
# Processing Record 10 of Set 11 | salamiyah
# Processing Record 11 of Set 11 | tuktoyaktuk
# Processing Record 12 of Set 11 | benguela
# Processing Record 13 of Set 11 | ostrovnoy
# Processing Record 14 of Set 11 | deputatskiy
# Processing Record 15 of Set 11 | de aar
# Processing Record 16 of Set 11 | tena
# Processing Record 17 of Set 11 | shirokiy
# Processing Record 18 of Set 11 | bar-le-duc
# Processing Record 19 of Set 11 | howell
# Processing Record 20 of Set 11 | iranshahr
# Processing Record 21 of Set 11 | muros
# Processing Record 22 of Set 11 | tamiahua
# Processing Record 23 of Set 11 | kununurra
# Processing Record 24 of Set 11 | kalmunai
# Processing Record 25 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 11 | aketi
# Processing Record 27 of Set 11 | kaka
# Processing Record 28 of Set 11 | sakaiminato
# Processing Record 29 of Set 11 | san carlos de bariloche
# Processing Record 30 of Set 11 | buchanan
# Processing Record 31 of Set 11 | yerbogachen
# Processing Record 32 of Set 11 | okha
# Processing Record 33 of Set 11 | palmer
# Processing Record 34 of Set 11 | emerald
# Processing Record 35 of Set 11 | serebryansk
# Processing Record 36 of Set 11 | laredo
# Processing Record 37 of Set 11 | balakhninskiy
# Processing Record 38 of Set 11 | ancud
# Processing Record 39 of Set 11 | mago
# Processing Record 40 of Set 11 | gualaquiza
# Processing Record 41 of Set 11 | iskateley
# Processing Record 42 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 11 | lavrentiya
# Processing Record 45 of Set 11 | baker city
# Processing Record 46 of Set 11 | totness
# Processing Record 47 of Set 11 | tambul
# City not found. Skipping...
# Processing Record 48 of Set 11 | ishinomaki
# Processing Record 49 of Set 11 | lompoc
# Processing Record 50 of Set 11 | boyolangu
# Processing Record 1 of Set 12 | sainte-marie
# Processing Record 2 of Set 12 | ust-karsk
# Processing Record 3 of Set 12 | mount darwin
# Processing Record 4 of Set 12 | show low
# Processing Record 5 of Set 12 | joensuu
# Processing Record 6 of Set 12 | am timan
# Processing Record 7 of Set 12 | akureyri
# Processing Record 8 of Set 12 | shuangcheng
# Processing Record 9 of Set 12 | nicoya
# Processing Record 10 of Set 12 | douentza
# Processing Record 11 of Set 12 | bonfim
# Processing Record 12 of Set 12 | nur
# Processing Record 13 of Set 12 | rawson
# Processing Record 14 of Set 12 | songjianghe
# Processing Record 15 of Set 12 | marsa matruh
# Processing Record 16 of Set 12 | vao
# Processing Record 17 of Set 12 | san luis
# Processing Record 18 of Set 12 | caohe
# Processing Record 19 of Set 12 | novokizhinginsk
# Processing Record 20 of Set 12 | galveston
# Processing Record 21 of Set 12 | youghal
# Processing Record 22 of Set 12 | hamilton
# Processing Record 23 of Set 12 | hals
# Processing Record 24 of Set 12 | asau
# Processing Record 25 of Set 12 | jesus carranza
# Processing Record 26 of Set 12 | xiaolingwei
# Processing Record 27 of Set 12 | puerto del rosario
# Processing Record 28 of Set 12 | vaitape
# Processing Record 29 of Set 12 | cabedelo
# Processing Record 30 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 31 of Set 12 | jiguani
# Processing Record 32 of Set 12 | castleford
# Processing Record 33 of Set 12 | teya
# Processing Record 34 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 35 of Set 12 | sergeyevka
# Processing Record 36 of Set 12 | hami
# Processing Record 37 of Set 12 | severo-yeniseyskiy
# Processing Record 38 of Set 12 | nhulunbuy
# Processing Record 39 of Set 12 | bunia
# Processing Record 40 of Set 12 | mericourt
# Processing Record 41 of Set 12 | palana
# Processing Record 42 of Set 12 | aswan
# Processing Record 43 of Set 12 | manavalakurichi
# Processing Record 44 of Set 12 | lusambo
# Processing Record 45 of Set 12 | bend
# Processing Record 46 of Set 12 | manzil salim
# Processing Record 47 of Set 12 | kananga
# Processing Record 48 of Set 12 | sao joao do piaui
# Processing Record 49 of Set 12 | horstel
# Processing Record 50 of Set 12 | aitape
# Processing Record 1 of Set 13 | diu
# Processing Record 2 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 3 of Set 13 | havoysund
# Processing Record 4 of Set 13 | kosovska mitrovica
# Processing Record 5 of Set 13 | manaquiri
# Processing Record 6 of Set 13 | puro
# Processing Record 7 of Set 13 | lundazi
# Processing Record 8 of Set 13 | saint george
# Processing Record 9 of Set 13 | muncar
# Processing Record 10 of Set 13 | gardan diwal
# City not found. Skipping...
# Processing Record 11 of Set 13 | dekar
# Processing Record 12 of Set 13 | lastoursville
# Processing Record 13 of Set 13 | high prairie
# Processing Record 14 of Set 13 | chalus
# Processing Record 15 of Set 13 | mogadishu
# Processing Record 16 of Set 13 | fukue
# Processing Record 17 of Set 13 | soyo
# Processing Record 18 of Set 13 | anadyr
# Processing Record 19 of Set 13 | kisangani
# Processing Record 20 of Set 13 | gizo
# Processing Record 21 of Set 13 | kismayo
# Processing Record 22 of Set 13 | botshabelo
# Processing Record 23 of Set 13 | dunedin
# Processing Record 24 of Set 13 | farafangana
# Processing Record 25 of Set 13 | formosa
# Processing Record 26 of Set 13 | jalu
# Processing Record 27 of Set 13 | kozachi laheri
# Processing Record 28 of Set 13 | voh
# Processing Record 29 of Set 13 | porto walter
# Processing Record 30 of Set 13 | roald
# Processing Record 31 of Set 13 | taltal
# Processing Record 32 of Set 13 | ouesso
# Processing Record 33 of Set 13 | sabha
# Processing Record 34 of Set 13 | bartica
# Processing Record 35 of Set 13 | clifton
# Processing Record 36 of Set 13 | rorvik
# Processing Record 37 of Set 13 | bethlehem
# Processing Record 38 of Set 13 | benton
# Processing Record 39 of Set 13 | rovaniemi
# Processing Record 40 of Set 13 | dandong
# Processing Record 41 of Set 13 | riacho de santana
# Processing Record 42 of Set 13 | nemuro
# Processing Record 43 of Set 13 | lavumisa
# Processing Record 44 of Set 13 | darnah
# Processing Record 45 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 13 | chaplynka
# Processing Record 47 of Set 13 | warrnambool
# Processing Record 48 of Set 13 | tura
# Processing Record 49 of Set 13 | myanaung
# Processing Record 50 of Set 13 | binzhou
# Processing Record 1 of Set 14 | riyadh
# Processing Record 2 of Set 14 | mantua
# Processing Record 3 of Set 14 | chupa
# Processing Record 4 of Set 14 | mbour
# Processing Record 5 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 14 | puerto carreno
# Processing Record 7 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 14 | xixiang
# Processing Record 9 of Set 14 | monrovia
# Processing Record 10 of Set 14 | puerto escondido
# Processing Record 11 of Set 14 | gudari
# Processing Record 12 of Set 14 | henties bay
# Processing Record 13 of Set 14 | garowe
# Processing Record 14 of Set 14 | mwinilunga
# Processing Record 15 of Set 14 | roebourne
# Processing Record 16 of Set 14 | praia da vitoria
# Processing Record 17 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 18 of Set 14 | el sauzal
# Processing Record 19 of Set 14 | tautira
# Processing Record 20 of Set 14 | aykhal
# Processing Record 21 of Set 14 | santa lucia
# Processing Record 22 of Set 14 | moree
# Processing Record 23 of Set 14 | toora-khem
# Processing Record 24 of Set 14 | elk grove
# Processing Record 25 of Set 14 | whitefish
# Processing Record 26 of Set 14 | asyut
# Processing Record 27 of Set 14 | atlantic city
# Processing Record 28 of Set 14 | nelson bay
# Processing Record 29 of Set 14 | buin
# Processing Record 30 of Set 14 | sioux lookout
# Processing Record 31 of Set 14 | ca mau
# Processing Record 32 of Set 14 | inirida
# Processing Record 33 of Set 14 | iralaya
# Processing Record 34 of Set 14 | oriental
# Processing Record 35 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 36 of Set 14 | oyama
# Processing Record 37 of Set 14 | flinders
# Processing Record 38 of Set 14 | sokolo
# Processing Record 39 of Set 14 | camopi
# Processing Record 40 of Set 14 | umm ruwabah
# City not found. Skipping...
# Processing Record 41 of Set 14 | nara
# Processing Record 42 of Set 14 | malakal
# Processing Record 43 of Set 14 | mozhaysk
# Processing Record 44 of Set 14 | racovita
# Processing Record 45 of Set 14 | montepuez
# Processing Record 46 of Set 14 | peru
# Processing Record 47 of Set 14 | maningrida
# Processing Record 48 of Set 14 | goundi
# Processing Record 49 of Set 14 | tamandare
# Processing Record 50 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 1 of Set 15 | sao felix do xingu
# Processing Record 2 of Set 15 | ambon
# Processing Record 3 of Set 15 | albert lea
# Processing Record 4 of Set 15 | khomutovka
# Processing Record 5 of Set 15 | linxia
# Processing Record 6 of Set 15 | pitsunda
# Processing Record 7 of Set 15 | banbury
# Processing Record 8 of Set 15 | ikom
# Processing Record 9 of Set 15 | alofi
# Processing Record 10 of Set 15 | santana do livramento
# Processing Record 11 of Set 15 | wukari
# Processing Record 12 of Set 15 | yuzhnyy
# Processing Record 13 of Set 15 | ligayan
# Processing Record 14 of Set 15 | askino
# Processing Record 15 of Set 15 | laguna
# Processing Record 16 of Set 15 | ajdabiya
# Processing Record 17 of Set 15 | sheridan
# Processing Record 18 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 19 of Set 15 | chino valley
# Processing Record 20 of Set 15 | dunkirk
# Processing Record 21 of Set 15 | manta
# Processing Record 22 of Set 15 | kamenka
# Processing Record 23 of Set 15 | kawalu
# Processing Record 24 of Set 15 | bangassou
# Processing Record 25 of Set 15 | santa cruz
# Processing Record 26 of Set 15 | karakose
# City not found. Skipping...
# Processing Record 27 of Set 15 | oussouye
# Processing Record 28 of Set 15 | sandwick
# Processing Record 29 of Set 15 | sidmouth
# Processing Record 30 of Set 15 | akhtubinsk
# Processing Record 31 of Set 15 | ipixuna
# Processing Record 32 of Set 15 | vila
# Processing Record 33 of Set 15 | kampot
# Processing Record 34 of Set 15 | barsovo
# Processing Record 35 of Set 15 | quatre cocos
# Processing Record 36 of Set 15 | katsuura
# Processing Record 37 of Set 15 | camabatela
# Processing Record 38 of Set 15 | goderich
# Processing Record 39 of Set 15 | west des moines
# Processing Record 40 of Set 15 | mezen
# Processing Record 41 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 15 | nchelenge
# Processing Record 43 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 15 | mayya
# Processing Record 45 of Set 15 | kanniyakumari
# Processing Record 46 of Set 15 | orange
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.tail()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 684          Mezen      RU  65.8522   44.2400     67.44        47          91
# 685      Nchelenge      ZM  -9.3451   28.7340     73.09        50           0
# 686          Mayya      RU  61.7333  130.2811     65.32        63         100
# 687  Kanniyakumari      IN   8.0833   77.5667     79.95        75         100
# 688         Orange      US  33.7000 -117.7675     77.77        85         100
#
#      Wind Speed Current Description
# 684        4.63     overcast clouds
# 685        8.08           clear sky
# 686        5.12     overcast clouds
# 687       24.65     overcast clouds
# 688        0.00     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
